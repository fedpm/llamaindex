# %%
# %pip install numexpr
# %pip install llama-index-llms-watsonx
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Seteo el nivel de logueo
# La cantidad de threads de numexpr
# Solicito el api key de watsonx y el api key

# %%
import logging
import sys


logging.basicConfig(stream=sys.stdout,level=logging.DEBUG);
logging.getLogger().addHandler(logging.StreamHandler(stream=sys.stdout))

# %%
# %pip install llama-index-llms-watsonx
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os

os.environ['NUMEXPR_MAX_THREADS']='4'
os.environ['NUMEXPR_NUM_THREADS']='2'

from llama_index.llms.watsonx import WatsonX

import getpass


credentials = {
    "url": "https://us-south.ml.cloud.ibm.com",
    "apikey": getpass.getpass("Please enter your WML api key (hit enter): ")
}

try:
    project_id = os.environ["PROJECT_ID"]
except KeyError:
    project_id = input("Please enter your project_id (hit enter): ")


llm = WatsonX(
    model_id="meta-llama/llama-2-70b-chat",
    credentials=credentials,
    project_id=project_id,
)

resp = llm.stream_complete("Paul Graham is")

# %%
for r in resp:
    print(r.delta, end="")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 for r in resp:
#       2     print(r.delta, end="")
#
# File c:\apps\Python\Python311\Lib\site-packages\llama_index\core\llms\callbacks.py:299, in llm_completion_callback.<locals>.wrap.<locals>.wrapped_llm_predict.<locals>.wrapped_gen()
#     297 def wrapped_gen() -> CompletionResponseGen:
#     298     last_response = None
# --> 299     for x in f_return_val:
#     300         dispatcher.event(
#     301             LLMCompletionEndEvent(
#     302                 prompt=str(args[0]),
#     303                 response=x,
#     304             )
#     305         )
#     306         yield cast(CompletionResponse, x)
#
# File c:\apps\Python\Python311\Lib\site-packages\llama_index\llms\watsonx\base.py:186, in WatsonX.stream_complete.<locals>.gen()
#     184 def gen() -> CompletionResponseGen:
# ...
